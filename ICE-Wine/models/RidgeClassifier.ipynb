# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import RidgeClassifier
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
import numpy as np

pd.set_option("display.max_columns", None)

df = pd.read_csv("./wine-training.csv")

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      13.71        1.86  2.36               16.6        101           2.61
# 1      13.88        5.04  2.23               20.0         80           0.98
# 2      12.29        1.41  1.98               16.0         85           2.55
# 3      12.21        1.19  1.75               16.8        151           1.85
# 4      12.82        3.37  2.30               19.5         88           1.48
# ..       ...         ...   ...                ...        ...            ...
# 114    13.86        1.51  2.67               25.0         86           2.95
# 115    12.25        1.73  2.12               19.0         80           1.65
# 116    14.38        1.87  2.38               12.0        102           3.30
# 117    12.69        1.53  2.26               20.7         80           1.38
# 118    12.34        2.45  2.46               21.0         98           2.56
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          2.88                  0.27             1.69             3.80  1.11
# 1          0.34                  0.40             0.68             4.90  0.58
# 2          2.50                  0.29             1.77             2.90  1.23
# 3          1.28                  0.14             2.50             2.85  1.28
# 4          0.66                  0.40             0.97            10.26  0.72
# ..          ...                   ...              ...              ...   ...
# 114        2.86                  0.21             1.87             3.38  1.36
# 115        2.03                  0.37             1.63             3.40  1.00
# 116        3.64                  0.29             2.96             7.50  1.20
# 117        1.46                  0.58             1.62             3.05  0.96
# 118        2.11                  0.34             1.31             2.80  0.80
#
#        od  proline  wine
# 0    4.00     1035     1
# 1    1.33      415     3
# 2    2.74      428     2
# 3    3.07      718     2
# 4    1.75      685     3
# ..    ...      ...   ...
# 114  3.16      410     2
# 115  3.17      510     2
# 116  3.00     1547     1
# 117  2.06      495     2
# 118  3.38      438     2
#
# [119 rows x 14 columns]

# %%
def preprocess(df):
   

    return df

df = preprocess(df)

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      13.71        1.86  2.36               16.6        101           2.61
# 1      13.88        5.04  2.23               20.0         80           0.98
# 2      12.29        1.41  1.98               16.0         85           2.55
# 3      12.21        1.19  1.75               16.8        151           1.85
# 4      12.82        3.37  2.30               19.5         88           1.48
# ..       ...         ...   ...                ...        ...            ...
# 114    13.86        1.51  2.67               25.0         86           2.95
# 115    12.25        1.73  2.12               19.0         80           1.65
# 116    14.38        1.87  2.38               12.0        102           3.30
# 117    12.69        1.53  2.26               20.7         80           1.38
# 118    12.34        2.45  2.46               21.0         98           2.56
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          2.88                  0.27             1.69             3.80  1.11
# 1          0.34                  0.40             0.68             4.90  0.58
# 2          2.50                  0.29             1.77             2.90  1.23
# 3          1.28                  0.14             2.50             2.85  1.28
# 4          0.66                  0.40             0.97            10.26  0.72
# ..          ...                   ...              ...              ...   ...
# 114        2.86                  0.21             1.87             3.38  1.36
# 115        2.03                  0.37             1.63             3.40  1.00
# 116        3.64                  0.29             2.96             7.50  1.20
# 117        1.46                  0.58             1.62             3.05  0.96
# 118        2.11                  0.34             1.31             2.80  0.80
#
#        od  proline  wine
# 0    4.00     1035     1
# 1    1.33      415     3
# 2    2.74      428     2
# 3    3.07      718     2
# 4    1.75      685     3
# ..    ...      ...   ...
# 114  3.16      410     2
# 115  3.17      510     2
# 116  3.00     1547     1
# 117  2.06      495     2
# 118  3.38      438     2
#
# [119 rows x 14 columns]

# %%
X = df.drop("wine", axis=1)
y = df[["wine"]]

ro = RandomOverSampler()
X_new, y_new = ro.fit_resample(X, y)


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.30, random_state=42
)

model = RidgeClassifier(random_state=42)


model.fit(X_train, y_train.values.ravel())

predictions = model.predict(X_test)


score = accuracy_score(y_test, predictions)

score
# Out:
# 0.9722222222222222

# %%
holdout = pd.read_csv("./wine-holdout.csv")

holdout = preprocess(holdout)
predictions = model.predict(holdout)

# %%
df = pd.DataFrame(predictions)
df.to_csv("nathan_lunceford-ice-wine-predictions.csv", index=False, header=["wine"])
