# %%
# Importing
import pandas as pd
import numpy as np
from pycaret.classification import *


pd.set_option("display.max_columns", None)


df = pd.read_csv("./grain-training.csv")

# %%
def preprocess(df):
    return df

# %%
df = preprocess(df)

# %%
setup = setup(df, target="Class")
# Out:
# <style type="text/css">
# #T_9c732_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9c732">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c732_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9c732_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c732_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c732_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9c732_row0_col1" class="data row0 col1" >6206</td>
#     </tr>
#     <tr>
#       <th id="T_9c732_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c732_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9c732_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_9c732_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_5ae9b th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
