# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from lightgbm import LGBMRegressor
import numpy as np  
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer


df = pd.read_csv(
    "https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/housing.csv"
)

crime_rate = pd.read_csv(
    "/home/nathan/Documents/School/cse450/module-03/crime_rate.csv"
)

# %%
# Convert 'date' to datetime and extract year and month
df["date"] = pd.to_datetime(df["date"])
df["year_of_sale"] = df["date"].dt.year
df["month_of_sale"] = df["date"].dt.month
df.drop("date", axis=1, inplace=True)  # Drop the original date column
df["age"] = 2015 - df["yr_built"]

# %%
df["has_basement"] = (df["sqft_basement"] > 0).astype(int)

# %%
numeric_features = [
    "bedrooms",
    "bathrooms",
    "sqft_living",
    "sqft_lot",
    "floors",
    "sqft_above",
    "sqft_basement",
    "yr_built",
    "yr_renovated",
    "lat",
    "long",
    "sqft_living15",
    "sqft_lot15",
]
categorical_features = ["waterfront", "view", "condition", "grade", "zipcode"]

# %%
# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the numeric features
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0      1565930130  0.675818   1.472832     1.827385 -0.260459  0.930885
# 1      3279000420 -0.397250  -0.474929    -0.674218 -0.181745 -0.917760
# 2       194000575  0.675818  -1.448810    -0.804736 -0.232122  0.006563
# 3      2115510160 -0.397250  -0.474929    -0.695971 -0.175448 -0.917760
# 4      7522500005 -1.470317  -0.799556    -0.326169 -0.258570 -0.917760
# ...           ...       ...        ...          ...       ...       ...
# 19995  5272200045 -0.397250  -0.799556    -1.174538 -0.204062 -0.917760
# 19996  9578500790 -0.397250   0.498952     1.095394 -0.252223  0.930885
# 19997  7202350480 -0.397250   0.498952     0.043633 -0.257815  0.930885
# 19998  1723049033 -2.543385  -1.773437    -1.848883 -0.000386 -0.917760
# 19999  6147650280  0.675818   0.498952     1.142163 -0.227110  0.930885
#
#        waterfront  view  condition  grade  ...  zipcode       lat      long  \
# 0               0     0          3      8  ...    98038 -1.254537  1.179542
# 1               0     0          2      7  ...    98023 -1.851593 -1.195227
# 2               0     2          3      7  ...    98116  0.042091 -1.244998
# 3               0     0          3      8  ...    98023 -1.741856 -1.252108
# 4               0     0          4      7  ...    98117  0.909158 -1.287658
# ...           ...   ...        ...    ...  ...      ...       ...       ...
# 19995           0     0          3      7  ...    98125  1.114914 -0.747292
# 19996           0     0          3      8  ...    98023 -1.895632 -0.960594
# 19997           0     0          3      7  ...    98053  0.873782  1.293303
# 19998           0     0          3      5  ...    98168 -0.570125 -0.775732
# 19999           0     0          3      7  ...    98042 -1.272586  0.816927
#
#        sqft_living15  sqft_lot15     price  year_of_sale  month_of_sale  age  \
# 0           1.887950   -0.321909  429900.0          2014             11    8
# 1          -0.987147   -0.180381  233000.0          2015              1   36
# 2          -0.126077   -0.256648  455000.0          2014             10  101
# 3          -0.286616   -0.194305  258950.0          2014             12   30
# 4          -0.432560   -0.250665  555000.0          2014              8   68
# ...              ...         ...       ...           ...            ...  ...
# 19995      -1.439573   -0.214286  378000.0          2014             11   68
# 19996       1.372767   -0.279436  399950.0          2014             11    1
# 19997      -0.432560   -0.372988  575000.0          2014              9   11
# 19998      -1.191468    0.083138  245000.0          2014              6   52
# 19999       1.508495   -0.249372  315000.0          2015              3    9
#
#        has_basement
# 0                 1
# 1                 1
# 2                 0
# 3                 0
# 4                 1
# ...             ...
# 19995             0
# 19996             0
# 19997             0
# 19998             0
# 19999             0
#
# [20000 rows x 24 columns]

# %%
# df = pd.get_dummies(df, columns=categorical_features, drop_first=True)
df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price', 'year_of_sale', 'month_of_sale',
#        'age', 'has_basement'],
#       dtype='object')

# %%
X = df.drop("price", axis=1)
y = df[["price"]]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=6)

# %%
model = LGBMRegressor(n_jobs=-1, random_state=7844)


model.fit(X_train, y_train)

predictions = model.predict(X_test)


# Calculate RMSE
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)

r2 = r2_score(y_test, predictions)

print(f"\n\nRMSE: {rmse}")
print(f"\n\nR^2: {r2}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004667 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2733
# [LightGBM] [Info] Number of data points in the train set: 18000, number of used features: 23
# [LightGBM] [Info] Start training from score 539596.451778
# RMSE: 105570.24896239345
#
#
# R^2: 0.9213539479808394

# %%
mini = pd.read_csv(
    "https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/housing_holdout_test_mini.csv"
)

# %%
# Convert 'date' to datetime and extract year and month
mini["date"] = pd.to_datetime(mini["date"])
mini["year_of_sale"] = mini["date"].dt.year
mini["month_of_sale"] = mini["date"].dt.month
mini.drop("date", axis=1, inplace=True)  # Drop the original date column

mini["has_basement"] = (mini["sqft_basement"] > 0).astype(int)

# Fit and transform the numeric features
mini[numeric_features] = scaler.fit_transform(mini[numeric_features])

# mini = pd.get_dummies(mini, columns=categorical_features, drop_first=True)

# %%
mini.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year_of_sale', 'month_of_sale',
#        'has_basement'],
#       dtype='object')

# %%
predictions = model.predict(mini)
df = pd.DataFrame(predictions)
df.to_csv("team3-module3-predictions.csv", index=False, header=["price"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 predictions = model.predict(mini)
#       2 df = pd.DataFrame(predictions)
#       3 df.to_csv("team3-module3-predictions.csv", index=False, header=["price"])
#
# File /usr/local/lib/python3.11/dist-packages/lightgbm/sklearn.py:937, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#     935 n_features = X.shape[1]
#     936 if self._n_features != n_features:
# --> 937     raise ValueError("Number of features of the model must "
#     938                      f"match the input. Model n_features_ is {self._n_features} and "
#     939                      f"input n_features is {n_features}")
#     940 # retrive original params that possibly can be used in both training and prediction
#     941 # and then overwrite them (considering aliases) with params that were passed directly in prediction
#     942 predict_params = self._process_params(stage="predict")
#
# ValueError: Number of features of the model must match the input. Model n_features_ is 23 and input n_features is 22
