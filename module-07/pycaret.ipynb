# %%
# Import
import pandas as pd
from pycaret.classification import *

pd.set_option("display.max_columns", None)

df = pd.read_csv(
    './datasets/spam-email+sms-dataset.csv', encoding='latin1'
)

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
def preprocess(df):
   
    return df

df = preprocess(df)
df
# Out:
#       spam                                            message
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567     1  This is the 2nd time we have tried 2 contact u...
# 5568     0              Will Ì_ b going to esplanade fr home?
# 5569     0  Pity, * was in mood for that. So...any other s...
# 5570     0  The guy did some bitching but I acted like i'd...
# 5571     0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
setup = setup(df, target="spam")
# Out:
# <style type="text/css">
# #T_b1b50_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b1b50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1b50_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b1b50_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1b50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1b50_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b1b50_row0_col1" class="data row0 col1" >7163</td>
#     </tr>
#     <tr>
#       <th id="T_b1b50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1b50_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b1b50_row1_col1" class="data row1 col1" >spam</td>
#     </tr>
#     <tr>
#       <th id="T_b1b50_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_52d05 th {
#   text-align: left;
# }
# #T_52d05_row0_col0, #T_52d05_row1_col0, #T_52d05_row1_col2, #T_52d05_row2_col0, #T_52d05_row3_col0, #T_52d05_row3_col2, #T_52d05_row4_col0, #T_52d05_row4_col2, #T_52d05_row5_col0, #T_52d05_row5_col2, #T_52d05_row6_col0, #T_52d05_row6_col2, #T_52d05_row7_col0, #T_52d05_row8_col0, #T_52d05_row8_col2, #T_52d05_row9_col0, #T_52d05_row9_col2, #T_52d05_row10_col0, #T_52d05_row11_col0, #T_52d05_row12_col0, #T_52d05_row12_col2, #T_52d05_row13_col0, #T_52d05_row13_col1, #T_52d05_row13_col2, #T_52d05_row13_col3, #T_52d05_row13_col4, #T_52d05_row13_col5, #T_52d05_row13_col6, #T_52d05_row13_col7 {
#   text-align: left;
# }
# ...

# %%
# best
